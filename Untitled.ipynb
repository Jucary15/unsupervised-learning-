# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
file_path = Path("crypto_data.csv")
df = pd.read_csv(file_path, index_col=0)
df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
df.shape
# Out:
# (1252, 6)

# %%
df[df['IsTrading']==True]
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 365       365Coin          X11       True   PoW/PoS              NaN
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 611     SixEleven      SHA-256       True       PoW              NaN
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...              ...
# SERO      1000000000
# UOS       1000000000
# BDX       1400222610
# ZEN         21000000
# XBC          1000000
#
# [1144 rows x 6 columns]

# %%
df = df[df['IsTrading']==True]
df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1144 entries, 42 to XBC
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CoinName         1144 non-null   object
#  1   Algorithm        1144 non-null   object
#  2   IsTrading        1144 non-null   bool
#  3   ProofType        1144 non-null   object
#  4   TotalCoinsMined  685 non-null    float64
#  5   TotalCoinSupply  1144 non-null   object
# dtypes: bool(1), float64(1), object(4)
# memory usage: 54.7+ KB

# %%
df.isnull().sum()
# Out:
# CoinName             0
# Algorithm            0
# IsTrading            0
# ProofType            0
# TotalCoinsMined    459
# TotalCoinSupply      0
# dtype: int64

# %%
crypto_df = df.dropna()
crypto_df.head()
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 808                0
# 1337    314159265359
# BTC         21000000

# %%
crypto_df = crypto_df[crypto_df['TotalCoinsMined']>0]

# %%
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 1337    EliteCoin          X13       True   PoW/PoS     2.927942e+10
# BTC       Bitcoin      SHA-256       True       PoW     1.792718e+07
# ETH      Ethereum       Ethash       True       PoW     1.076842e+08
# ...           ...          ...        ...       ...              ...
# ZEPH       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# GAP       Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 1337    314159265359
# BTC         21000000
# ETH                0
# ...              ...
# ZEPH      2000000000
# GAP        250000000
# BDX       1400222610
# ZEN         21000000
# XBC          1000000
#
# [532 rows x 6 columns]

# %%
crypto_df.drop(['IsTrading','CoinName'], axis=1, inplace=True)
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
for i in crypto_df.columns:
    print(f'{i}: {crypto_df[i].nunique()}')
# Out:
# Algorithm: 71
# ProofType: 25
# TotalCoinsMined: 518
# TotalCoinSupply: 280

# %%
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
X
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# ...               ...             ...                               ...
# ZEPH     2.000000e+09      2000000000                                 0
# GAP      1.493105e+07       250000000                                 0
# BDX      9.802226e+08      1400222610                                 0
# ZEN      7.296538e+06        21000000                                 0
# XBC      1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# 404               0                  0                   0                0
# 1337              0                  0                   0                0
# BTC               0                  0                   0                0
# ETH               0                  0                   0                0
# ...             ...                ...                 ...              ...
# ZEPH              0                  0                   0                0
# GAP               0                  0                   0                0
# BDX               0                  0                   0                0
# ZEN               0                  0                   0                0
# XBC               0                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 42                    0                  0              0  ...
# 404                   0                  0              0  ...
# 1337                  0                  0              0  ...
# BTC                   0                  0              0  ...
# ETH                   0                  0              0  ...
# ...                 ...                ...            ...  ...
# ZEPH                  0                  0              0  ...
# GAP                   0                  0              0  ...
# BDX                   0                  0              0  ...
# ZEN                   0                  0              0  ...
# XBC                   0                  0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 42                    1                   0                  0
# 404                   1                   0                  0
# 1337                  1                   0                  0
# BTC                   0                   0                  0
# ETH                   0                   0                  0
# ...                 ...                 ...                ...
# ZEPH                  0                   0                  0
# GAP                   1                   0                  0
# BDX                   0                   0                  0
# ZEN                   0                   0                  0
# XBC                   0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 42                     0              0                             0
# 404                    0              0                             0
# 1337                   0              0                             0
# BTC                    0              0                             0
# ETH                    0              0                             0
# ...                  ...            ...                           ...
# ZEPH                   0              0                             0
# GAP                    0              0                             0
# BDX                    0              0                             0
# ZEN                    0              0                             0
# XBC                    0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 42                           0               0
# 404                          0               0
# 1337                         0               0
# BTC                          0               0
# ETH                          0               0
# ...                        ...             ...
# ZEPH                         0               0
# GAP                          0               0
# BDX                          0               0
# ZEN                          0               0
# XBC                          0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTC                                0                   0
# ETH                                0                   0
# ...                              ...                 ...
# ZEPH                               0                   0
# GAP                                0                   0
# BDX                                0                   0
# ZEN                                0                   0
# XBC                                0                   0
#
# [532 rows x 98 columns]

# %%
# Standarize data with StandarScaler
X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.13217937, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.15255998, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.15285552, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %%
X_scaled.shape
# Out:
# (532, 98)

# %%
# PCA to reduce dimensions and preserve 90% of the data
from sklearn.decomposition import PCA
# PCA model
pca = PCA(n_components=0.90)
# Two principal components for the iris data.
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca.shape
# Out:
# (532, 74)

# %%
# t-SNE model on the dataframe X_pca to reduce dimensions to 2
from sklearn.manifold import TSNE
tsne = TSNE(perplexity=50)

# %%
# Reduce dimensions
X_pca_tsne_features = tsne.fit_transform(X_pca)
X_pca_tsne_features

X_pca_tsne_features.shape
# Out:
# (532, 2)

# %%
plt.scatter(X_pca_tsne_features[:, 0], X_pca_tsne_features[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
inertia = []
k = list(range(1, 11))
# Inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(X_pca_tsne_features)
#     km.predict
    inertia.append(km.inertia_)
# Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
X_pca_tsne_features_elbow = pd.DataFrame(elbow_data)
X_pca_tsne_features_elbow.head(10)
# Out:
#     k       inertia
# 0   1  63595.660156
# 1   2  36330.261719
# 2   3  26043.101562
# 3   4  19645.984375
# 4   5  14199.132812
# 5   6  10555.111328
# 6   7   8031.592285
# 7   8   7041.424316
# 8   9   5989.436035
# 9  10   5016.923828

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(X_pca_tsne_features_elbow['k'], X_pca_tsne_features_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('clusters')
plt.ylabel('inertia')
plt.title('curve for customer data')
plt.show()

# %%
# future clusters
predictions = model.predict(X_pca_tsne_features)
predictions
# Out:
# array([3, 3, 3, 1, 6, 6, 4, 6, 6, 6, 2, 6, 1, 1, 2, 4, 2, 6, 3, 3, 6, 6,
#        1, 6, 6, 3, 3, 0, 6, 3, 2, 3, 2, 2, 0, 0, 6, 1, 6, 2, 6, 2, 1, 6,
#        2, 0, 6, 6, 6, 3, 2, 6, 4, 1, 6, 6, 2, 3, 6, 2, 1, 2, 1, 1, 3, 6,
#        1, 6, 3, 0, 3, 3, 3, 2, 6, 6, 2, 4, 1, 6, 1, 4, 4, 1, 1, 1, 2, 3,
#        3, 6, 2, 2, 6, 4, 6, 1, 3, 3, 0, 0, 0, 1, 6, 1, 0, 6, 1, 6, 3, 2,
#        1, 6, 3, 3, 6, 2, 2, 6, 3, 2, 3, 6, 2, 2, 1, 6, 4, 3, 2, 1, 1, 3,
#        0, 0, 6, 6, 1, 6, 3, 6, 1, 4, 2, 1, 4, 6, 6, 1, 4, 6, 1, 1, 4, 3,
#        1, 0, 6, 6, 6, 4, 1, 1, 0, 1, 2, 2, 4, 1, 1, 4, 4, 2, 1, 3, 3, 3,
#        3, 2, 2, 6, 4, 3, 0, 1, 1, 4, 3, 6, 3, 6, 1, 1, 2, 6, 2, 1, 3, 4,
#        6, 1, 3, 3, 1, 2, 6, 6, 0, 4, 6, 0, 3, 4, 1, 3, 3, 0, 1, 4, 1, 3,
#        2, 3, 3, 4, 0, 3, 1, 3, 3, 3, 3, 2, 0, 1, 3, 1, 4, 3, 0, 3, 6, 1,
#        0, 2, 3, 0, 6, 3, 6, 1, 1, 6, 4, 3, 4, 6, 1, 4, 4, 1, 4, 3, 3, 3,
#        1, 4, 2, 1, 1, 1, 3, 4, 1, 6, 1, 6, 3, 2, 6, 6, 0, 4, 2, 4, 4, 6,
#        3, 6, 2, 2, 3, 0, 3, 0, 6, 2, 3, 0, 4, 1, 4, 1, 4, 6, 1, 6, 2, 6,
#        6, 6, 3, 3, 0, 2, 1, 4, 6, 0, 0, 3, 0, 2, 6, 3, 1, 4, 4, 6, 3, 3,
#        6, 3, 3, 1, 2, 0, 6, 0, 4, 0, 4, 3, 6, 3, 0, 0, 6, 4, 3, 0, 6, 3,
#        3, 6, 4, 4, 0, 0, 3, 0, 6, 3, 3, 2, 2, 1, 2, 1, 6, 2, 0, 2, 3, 0,
#        6, 6, 2, 3, 3, 2, 2, 6, 0, 2, 6, 4, 2, 1, 1, 6, 0, 2, 2, 4, 3, 3,
#        6, 1, 6, 1, 1, 3, 1, 0, 3, 1, 0, 3, 3, 4, 1, 0, 2, 1, 6, 0, 6, 0,
#        3, 1, 2, 2, 0, 3, 4, 6, 3, 1, 0, 3, 2, 2, 3, 3, 3, 1, 2, 3, 2, 3,
#        6, 2, 2, 6, 2, 4, 1, 1, 1, 2, 2, 2, 3, 2, 3, 3, 6, 2, 6, 1, 2, 2,
#        0, 3, 1, 1, 6, 6, 6, 3, 6, 3, 6, 3, 3, 3, 2, 3, 2, 2, 4, 1, 3, 1,
#        4, 0, 3, 6, 4, 0, 3, 1, 3, 1, 3, 4, 6, 3, 1, 4, 1, 3, 6, 3, 0, 4,
#        3, 1, 2, 6, 2, 1, 0, 1, 3, 0, 6, 3, 6, 0, 6, 0, 1, 3, 1, 0, 1, 1,
#        3, 0, 6, 1])

# %%
The cryptocurrency data has no true evidence of clutters.
